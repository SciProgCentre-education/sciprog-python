# %% [markdown]
# # USB
#
# * libusb/ OpenUSB
# * [PyUSB](https://github.com/pyusb/pyusb)

# %%
# !sudo apt-get install libusb-1.0-0

# %%
# !pip install pyusb

# %%
import usb.core
import usb.util


devices = usb.core.find(find_all=True)

for dev in devices:
    print(dev)
# Out:
# DEVICE ID 046d:084b on Bus 005 Address 012 =================
#  bLength                :   0x12 (18 bytes)
#  bDescriptorType        :    0x1 Device
#  bcdUSB                 :  0x200 USB 2.0
#  bDeviceClass           :   0xef Miscellaneous
#  bDeviceSubClass        :    0x2
#  bDeviceProtocol        :    0x1
#  bMaxPacketSize0        :   0x40 (64 bytes)
#  idVendor               : 0x046d
#  idProduct              : 0x084b
#  bcdDevice              :   0x13 Device 0.13
#  iManufacturer          :    0x0
#  iProduct               :    0x2 Error Accessing String
#  iSerialNumber          :    0x1 Error Accessing String
#  bNumConfigurations     :    0x1
#   CONFIGURATION 1: 0 mA ====================================
#    bLength              :    0x9 (9 bytes)
#    bDescriptorType      :    0x2 Configuration
#    wTotalLength         :  0x93a (2362 bytes)
#    bNumInterfaces       :    0x3
#    bConfigurationValue  :    0x1
#    iConfiguration       :    0x0
# ...

# %% [markdown]
# ## HID

# %%
# !pip install hid

# %% [markdown]
# ## FTDI
#
# ![RS-232](https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/RS-232.jpeg/220px-RS-232.jpeg)
#
# * RS-232 -> USB
#
# ![](./usb-ftdi.svg)

# %%
# !pip install pyftdi pylibftdi ftd2xx
